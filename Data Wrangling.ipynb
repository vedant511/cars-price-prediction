# %% [markdown]
# # Import Dependencies, Data & take first look

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statistics import mode
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# # Outliers Analysis

# %% [markdown]
# Make sure Very high Engine HP values are not outliers

# %%
data[data['Engine HP'] > 500]
# Out:
#                Make           Model  Year             Engine Fuel Type  \
# 466         Ferrari      458 Italia  2013  premium unleaded (required)
# 467         Ferrari      458 Italia  2013  premium unleaded (required)
# 468         Ferrari      458 Italia  2014  premium unleaded (required)
# 469         Ferrari      458 Italia  2014  premium unleaded (required)
# 470         Ferrari      458 Italia  2014  premium unleaded (required)
# 471         Ferrari      458 Italia  2015  premium unleaded (required)
# 472         Ferrari      458 Italia  2015  premium unleaded (required)
# 473         Ferrari      458 Italia  2015  premium unleaded (required)
# 604         McLaren            570S  2016  premium unleaded (required)
# 605         Ferrari            575M  2002  premium unleaded (required)
# 606         Ferrari            575M  2002  premium unleaded (required)
# 607         Ferrari            575M  2003  premium unleaded (required)
# 608         Ferrari            575M  2003  premium unleaded (required)
# 609         Ferrari            575M  2004  premium unleaded (required)
# 610         Ferrari            575M  2004  premium unleaded (required)
# 611         Maybach              57  2010  premium unleaded (required)
# 612         Maybach              57  2010  premium unleaded (required)
# 613         Maybach              57  2010  premium unleaded (required)
# 614         Maybach              57  2011  premium unleaded (required)
# 615         Maybach              57  2011  premium unleaded (required)
# 616         Maybach              57  2012  premium unleaded (required)
# 617         Maybach              57  2012  premium unleaded (required)
# 618         Ferrari             599  2009  premium unleaded (required)
# 619         Ferrari             599  2009  premium unleaded (required)
# 620         Ferrari             599  2010  premium unleaded (required)
# 621         Ferrari             599  2011  premium unleaded (required)
# 622         Ferrari             599  2011  premium unleaded (required)
# 682         Ferrari  612 Scaglietti  2009  premium unleaded (required)
# 683         Ferrari  612 Scaglietti  2010  premium unleaded (required)
# 684         Ferrari  612 Scaglietti  2011  premium unleaded (required)
# ...             ...             ...   ...                          ...
# 11210  Aston Martin        Vanquish  2016  premium unleaded (required)
# 11211  Aston Martin        Vanquish  2016  premium unleaded (required)
# 11212  Aston Martin        Vanquish  2016  premium unleaded (required)
# 11213  Aston Martin        Vanquish  2016  premium unleaded (required)
# 11362       Bugatti     Veyron 16.4  2008  premium unleaded (required)
# 11363       Bugatti     Veyron 16.4  2008  premium unleaded (required)
# 11364       Bugatti     Veyron 16.4  2009  premium unleaded (required)
# 11380         Dodge           Viper  2015  premium unleaded (required)
# 11381         Dodge           Viper  2015  premium unleaded (required)
# 11382         Dodge           Viper  2015  premium unleaded (required)
# 11383         Dodge           Viper  2015  premium unleaded (required)
# 11384         Dodge           Viper  2016  premium unleaded (required)
# 11385         Dodge           Viper  2016  premium unleaded (required)
# 11386         Dodge           Viper  2016  premium unleaded (required)
# 11387         Dodge           Viper  2016  premium unleaded (required)
# 11388         Dodge           Viper  2016  premium unleaded (required)
# 11389         Dodge           Viper  2017  premium unleaded (required)
# 11390         Dodge           Viper  2017  premium unleaded (required)
# 11391         Dodge           Viper  2017  premium unleaded (required)
# 11392         Dodge           Viper  2017  premium unleaded (required)
# 11393         Dodge           Viper  2017  premium unleaded (required)
# 11448   Rolls-Royce          Wraith  2014  premium unleaded (required)
# 11449   Rolls-Royce          Wraith  2015  premium unleaded (required)
# 11450   Rolls-Royce          Wraith  2016  premium unleaded (required)
# 11508           BMW            X5 M  2015  premium unleaded (required)
# 11509           BMW            X5 M  2016  premium unleaded (required)
# 11510           BMW            X5 M  2017  premium unleaded (required)
# 11523           BMW            X6 M  2015  premium unleaded (required)
# 11524           BMW            X6 M  2016  premium unleaded (required)
# 11525           BMW            X6 M  2017  premium unleaded (required)
#
#        Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# 466        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 467        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 468        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 469        597.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 470        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 471        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 472        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 473        597.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 604        562.0               8.0  AUTOMATED_MANUAL  rear wheel drive
# 605        515.0              12.0            MANUAL  rear wheel drive
# 606        515.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 607        515.0              12.0            MANUAL  rear wheel drive
# 608        515.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 609        515.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 610        515.0              12.0            MANUAL  rear wheel drive
# 611        543.0              12.0         AUTOMATIC  rear wheel drive
# 612        631.0              12.0         AUTOMATIC  rear wheel drive
# 613        604.0              12.0         AUTOMATIC  rear wheel drive
# 614        543.0              12.0         AUTOMATIC  rear wheel drive
# 615        620.0              12.0         AUTOMATIC  rear wheel drive
# 616        543.0              12.0         AUTOMATIC  rear wheel drive
# 617        620.0              12.0         AUTOMATIC  rear wheel drive
# 618        611.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 619        611.0              12.0            MANUAL  rear wheel drive
# 620        611.0              12.0            MANUAL  rear wheel drive
# 621        611.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 622        661.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 682        532.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 683        532.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# 684        532.0              12.0  AUTOMATED_MANUAL  rear wheel drive
# ...          ...               ...               ...               ...
# 11210      568.0              12.0         AUTOMATIC  rear wheel drive
# 11211      568.0              12.0         AUTOMATIC  rear wheel drive
# 11212      568.0              12.0         AUTOMATIC  rear wheel drive
# 11213      568.0              12.0         AUTOMATIC  rear wheel drive
# 11362     1001.0              16.0  AUTOMATED_MANUAL   all wheel drive
# 11363     1001.0              16.0  AUTOMATED_MANUAL   all wheel drive
# 11364     1001.0              16.0  AUTOMATED_MANUAL   all wheel drive
# 11380      645.0              10.0            MANUAL  rear wheel drive
# 11381      645.0              10.0            MANUAL  rear wheel drive
# 11382      645.0              10.0            MANUAL  rear wheel drive
# 11383      645.0              10.0            MANUAL  rear wheel drive
# 11384      645.0              10.0            MANUAL  rear wheel drive
# 11385      645.0              10.0            MANUAL  rear wheel drive
# 11386      645.0              10.0            MANUAL  rear wheel drive
# 11387      645.0              10.0            MANUAL  rear wheel drive
# 11388      645.0              10.0            MANUAL  rear wheel drive
# 11389      645.0              10.0            MANUAL  rear wheel drive
# 11390      645.0              10.0            MANUAL  rear wheel drive
# 11391      645.0              10.0            MANUAL  rear wheel drive
# 11392      645.0              10.0            MANUAL  rear wheel drive
# 11393      645.0              10.0            MANUAL  rear wheel drive
# 11448      624.0              12.0         AUTOMATIC  rear wheel drive
# 11449      624.0              12.0         AUTOMATIC  rear wheel drive
# 11450      624.0              12.0         AUTOMATIC  rear wheel drive
# 11508      567.0               8.0         AUTOMATIC   all wheel drive
# 11509      567.0               8.0         AUTOMATIC   all wheel drive
# 11510      567.0               8.0         AUTOMATIC   all wheel drive
# 11523      567.0               8.0         AUTOMATIC   all wheel drive
# 11524      567.0               8.0         AUTOMATIC   all wheel drive
# 11525      567.0               8.0         AUTOMATIC   all wheel drive
#
#        Number of Doors                                  Market Category  \
# 466                2.0                          Exotic,High-Performance
# 467                2.0                          Exotic,High-Performance
# 468                2.0                          Exotic,High-Performance
# 469                2.0                          Exotic,High-Performance
# 470                2.0                          Exotic,High-Performance
# 471                2.0                          Exotic,High-Performance
# 472                2.0                          Exotic,High-Performance
# 473                2.0                          Exotic,High-Performance
# 604                2.0                          Exotic,High-Performance
# 605                2.0                          Exotic,High-Performance
# 606                2.0                          Exotic,High-Performance
# 607                2.0                          Exotic,High-Performance
# 608                2.0                          Exotic,High-Performance
# 609                2.0                          Exotic,High-Performance
# 610                2.0                          Exotic,High-Performance
# 611                4.0                                    Exotic,Luxury
# 612                4.0                   Exotic,Luxury,High-Performance
# 613                4.0                   Exotic,Luxury,High-Performance
# 614                4.0                                    Exotic,Luxury
# 615                4.0                   Exotic,Luxury,High-Performance
# 616                4.0                                    Exotic,Luxury
# 617                4.0                        Exotic,Luxury,Performance
# 618                2.0                          Exotic,High-Performance
# 619                2.0                          Exotic,High-Performance
# 620                2.0                          Exotic,High-Performance
# 621                2.0                          Exotic,High-Performance
# 622                2.0            Exotic,Factory Tuner,High-Performance
# 682                2.0                          Exotic,High-Performance
# 683                2.0                          Exotic,High-Performance
# 684                2.0                          Exotic,High-Performance
# ...                ...                                              ...
# 11210              2.0                          Exotic,High-Performance
# 11211              2.0                          Exotic,High-Performance
# 11212              2.0                          Exotic,High-Performance
# 11213              2.0                          Exotic,High-Performance
# 11362              2.0                          Exotic,High-Performance
# 11363              2.0                          Exotic,High-Performance
# 11364              2.0                          Exotic,High-Performance
# 11380              2.0                          Exotic,High-Performance
# 11381              2.0                          Exotic,High-Performance
# 11382              2.0                          Exotic,High-Performance
# 11383              2.0                          Exotic,High-Performance
# 11384              2.0                          Exotic,High-Performance
# 11385              2.0                          Exotic,High-Performance
# 11386              2.0                          Exotic,High-Performance
# 11387              2.0                          Exotic,High-Performance
# 11388              2.0                          Exotic,High-Performance
# 11389              2.0                          Exotic,High-Performance
# 11390              2.0                          Exotic,High-Performance
# 11391              2.0                          Exotic,High-Performance
# 11392              2.0                          Exotic,High-Performance
# 11393              2.0                          Exotic,High-Performance
# 11448              2.0                   Exotic,Luxury,High-Performance
# 11449              2.0                   Exotic,Luxury,High-Performance
# 11450              2.0                   Exotic,Luxury,High-Performance
# 11508              4.0  Crossover,Factory Tuner,Luxury,High-Performance
# 11509              4.0  Crossover,Factory Tuner,Luxury,High-Performance
# 11510              4.0  Crossover,Factory Tuner,Luxury,High-Performance
# 11523              4.0  Crossover,Factory Tuner,Luxury,High-Performance
# 11524              4.0  Crossover,Factory Tuner,Luxury,High-Performance
# 11525              4.0  Crossover,Factory Tuner,Luxury,High-Performance
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity     MSRP
# 466        Compact   Convertible           17        13        2774   257412
# 467        Compact         Coupe           17        13        2774   233509
# 468        Compact         Coupe           17        13        2774   233509
# 469        Compact         Coupe           17        13        2774   288000
# 470        Compact   Convertible           17        13        2774   257412
# 471        Compact         Coupe           17        13        2774   239340
# 472        Compact   Convertible           17        13        2774   263553
# 473        Compact         Coupe           17        13        2774   291744
# 604        Compact         Coupe           23        16         416   184900
# 605        Compact         Coupe           15         9        2774   214670
# 606        Compact         Coupe           16         9        2774   224670
# 607        Compact         Coupe           15         9        2774   217890
# 608        Compact         Coupe           16         9        2774   228339
# 609        Compact         Coupe           16         9        2774   228339
# 610        Compact         Coupe           15         9        2774   217890
# 611          Large         Sedan           16        10          67   366000
# 612          Large         Sedan           16        10          67   455500
# 613          Large         Sedan           16        10          67   405500
# 614          Large         Sedan           16        10          67   372500
# 615          Large         Sedan           16        10          67   412000
# 616          Large         Sedan           16        10          67   379050
# 617          Large         Sedan           16        10          67   418950
# 618        Midsize         Coupe           15        11        2774   320580
# 619        Midsize         Coupe           15        11        2774   310543
# 620        Midsize         Coupe           15        11        2774   310543
# 621        Midsize         Coupe           15        11        2774   320580
# 622        Midsize         Coupe           15        11        2774   410000
# 682          Large         Coupe           16         9        2774   313088
# 683          Large         Coupe           16         9        2774   313088
# 684          Large         Coupe           16         9        2774   313088
# ...            ...           ...          ...       ...         ...      ...
# 11210      Midsize         Coupe           21        13         259   287650
# 11211      Midsize   Convertible           21        13         259   305650
# 11212      Midsize         Coupe           21        13         259   302695
# 11213      Midsize   Convertible           21        13         259   320695
# 11362      Compact         Coupe           14         8         820  2065902
# 11363      Compact         Coupe           14         8         820  1500000
# 11364      Compact         Coupe           14         8         820  1705769
# 11380      Compact         Coupe           21        12        1851   107995
# 11381      Compact         Coupe           21        12        1851    94995
# 11382      Compact         Coupe           21        12        1851    84995
# 11383      Compact         Coupe           21        12        1851    94995
# 11384      Compact         Coupe           21        12        1851    95895
# 11385      Compact         Coupe           21        12        1851    87895
# 11386      Compact         Coupe           21        12        1851   118795
# 11387      Compact         Coupe           21        12        1851   107995
# 11388      Compact         Coupe           21        12        1851    95895
# 11389      Compact         Coupe           19        12        1851    95895
# 11390      Compact         Coupe           19        12        1851    87895
# 11391      Compact         Coupe           19        12        1851   118795
# 11392      Compact         Coupe           19        12        1851    95895
# 11393      Compact         Coupe           19        12        1851   107995
# 11448        Large         Coupe           21        13          86   284900
# 11449        Large         Coupe           21        13          86   294025
# 11450        Large         Coupe           21        13          86   304350
# 11508      Midsize       4dr SUV           19        14        3916    98700
# 11509      Midsize       4dr SUV           19        14        3916    98800
# 11510      Midsize       4dr SUV           19        14        3916    98800
# 11523      Midsize       4dr SUV           19        14        3916   102100
# 11524      Midsize       4dr SUV           19        14        3916   102200
# 11525      Midsize       4dr SUV           19        14        3916   102200
#
# [492 rows x 16 columns]

# %% [markdown]
# Check which car has 354 mpg and 137 mpg highway and city mileage respectively (These values are crazily high)

# %%
data[data['highway MPG'] == 354]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1119          Luxury      Midsize         Sedan          354        24
#
#       Popularity   MSRP
# 1119        3105  51600

# %%
data[data['city mpg'] == 137]
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790  BMW    i3  2015         electric      170.0               0.0
# 5791  BMW    i3  2016         electric      170.0               0.0
# 5792  BMW    i3  2017         electric      170.0               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5790      Compact  4dr Hatchback          111       137        3916  42400
# 5791      Compact  4dr Hatchback          111       137        3916  42400
# 5792      Compact  4dr Hatchback          111       137        3916  42400

# %% [markdown]
# The 354 highway mpg clearly looks insane for Audi A6 as it's city mpg is 24. Let's analyze other Audi A6 cars from 2017 to check what's their highway mileage. It could be that instead of 354, the true mpg is 35.4

# %%
data[(data['Make'] == 'Audi') & (data['Model'] == 'A6') & (data['Year'] == 2017)]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1114  Audi    A6  2017  premium unleaded (recommended)      252.0
# 1115  Audi    A6  2017     premium unleaded (required)      333.0
# 1116  Audi    A6  2017     premium unleaded (required)      340.0
# 1117  Audi    A6  2017     premium unleaded (required)      333.0
# 1118  Audi    A6  2017  premium unleaded (recommended)      252.0
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
# 1120  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1114               4.0         AUTOMATIC    all wheel drive              4.0
# 1115               6.0         AUTOMATIC    all wheel drive              4.0
# 1116               6.0         AUTOMATIC    all wheel drive              4.0
# 1117               6.0         AUTOMATIC    all wheel drive              4.0
# 1118               4.0         AUTOMATIC    all wheel drive              4.0
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
# 1120               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#          Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1114              Luxury      Midsize         Sedan           31        22
# 1115  Luxury,Performance      Midsize         Sedan           31        22
# 1116  Luxury,Performance      Midsize         Sedan           31        22
# 1117  Luxury,Performance      Midsize         Sedan           29        21
# 1118              Luxury      Midsize         Sedan           32        22
# 1119              Luxury      Midsize         Sedan          354        24
# 1120              Luxury      Midsize         Sedan           34        24
#
#       Popularity   MSRP
# 1114        3105  53800
# 1115        3105  61600
# 1116        3105  67600
# 1117        3105  58600
# 1118        3105  49800
# 1119        3105  51600
# 1120        3105  47600

# %% [markdown]
# So, it's definitely is an outlier and we will change the value from 354 to 35.4 based on other records

# %%
data.at[1119, 'highway MPG'] = 35.4

# %%
data.iloc[1119]
# Out:
# Make                                           Audi
# Model                                            A6
# Year                                           2017
# Engine Fuel Type     premium unleaded (recommended)
# Engine HP                                       252
# Engine Cylinders                                  4
# Transmission Type                  AUTOMATED_MANUAL
# Driven_Wheels                     front wheel drive
# Number of Doors                                   4
# Market Category                              Luxury
# Vehicle Size                                Midsize
# Vehicle Style                                 Sedan
# highway MPG                                      35
# city mpg                                         24
# Popularity                                     3105
# MSRP                                          51600
# Name: 1119, dtype: object

# %% [markdown]
# Same check for BMW i3 for city mpg of 137

# %%
data[(data['Make'] == 'BMW') & (data['Model'] == 'i3') & (data['Year'] >= 2015)]
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790  BMW    i3  2015         electric      170.0               0.0
# 5791  BMW    i3  2016         electric      170.0               0.0
# 5792  BMW    i3  2017         electric      170.0               0.0
# 5793  BMW    i3  2017         electric      170.0               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5793      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5790      Compact  4dr Hatchback          111       137        3916  42400
# 5791      Compact  4dr Hatchback          111       137        3916  42400
# 5792      Compact  4dr Hatchback          111       137        3916  42400
# 5793      Compact  4dr Hatchback          106       129        3916  43600

# %% [markdown]
# Upon further research found out that BMW i3 has greater city mpg than highway mpg

# %% [markdown]
# # Missing values analysis

# %%
def missing_zero_values_table(df):
    zero_val = (df == 0.00).astype(int).sum(axis=0)
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
    mz_table = mz_table.rename(
    columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
    mz_table['Data Type'] = df.dtypes
    mz_table = mz_table[
        mz_table.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
        "There are " + str(mz_table.shape[0]) +
          " columns that have missing values.")
    return mz_table

# %%
missing_zero_values_table(data)
# Out:
# Your selected dataframe has 16 columns and 11914 Rows.
# There are 5 columns that have missing values.
#                   Zero Values  Missing Values  % of Total Values Data Type
# Market Category             0            3742               31.4    object
# Engine HP                   0              69                0.6   float64
# Engine Cylinders           56              30                0.3   float64
# Number of Doors             0               6                0.1   float64
# Engine Fuel Type            0               3                0.0    object

# %% [markdown]
# Let's analyze these variables one by one to check if missing data is random or because of any reason

# %%
data[data['Engine HP'].isna()]

# %%
data[data['Number of Doors'].isna()]

# %%
data[data['Engine Cylinders'].isna()]

# %%
data[data['Engine Fuel Type'].isna()]
# Out:
#          Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %% [markdown]
# Functions to handle missing values

# %%
def handle_missing_doors(df):
    for idx, row in df.iterrows():
        if pd.isnull(row['Number of Doors']):
            value = mode(df[(df['Model']==row['Model']) & 
                        (df['Make']==row['Make']) & 
                        (df['Year']==row['Year'])]['Number of Doors'])
            if pd.isnull(value):
                df.at[idx, 'Number of Doors'] = 4
            else:
                df.at[idx, 'Number of Doors'] = value
            

def handle_missing_fuel_type(df):
    for idx, row in df.iterrows():
        if pd.isnull(row['Engine Fuel Type']):
            try:
                value = mode(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine Fuel Type'])
            except Exception as e:
                value = np.mean(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine Fuel Type'])
            if pd.isnull(value):
                df.at[idx, 'Engine Fuel Type'] = 'NA'
            else:
                df.at[idx, 'Engine Fuel Type'] = value
            
            
def handle_missing_eng_cyl(df):
    for idx, row in df.iterrows():
        if pd.isnull(row['Engine Cylinders']):
            try:
                value = mode(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine Cylinders'])
            except Exception as e:
                value = np.mean(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine Cylinders'])
            if pd.isnull(value):
                df.at[idx, 'Engine Cylinders'] = 0
            else:
                df.at[idx, 'Engine Cylinders'] = value
                
                
def handle_missing_eng_hp(df):
    for idx, row in df.iterrows():
        if pd.isnull(row['Engine HP']):
            try:
                value = mode(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine HP'])
            except Exception as e:
                value = np.mean(df[(df['Model']==row['Model']) & 
                               (df['Make']==row['Make']) & 
                              (df['Year']==row['Year'])]['Engine HP'])
            if pd.isnull(value):
                df.at[idx, 'Engine HP'] = 0
            else:
                df.at[idx, 'Engine HP'] = value

# %%
handle_missing_doors(data)
handle_missing_eng_cyl(data)
handle_missing_eng_hp(data)
handle_missing_fuel_type(data)

# %% [markdown]
# Drop the Market Category Column as it has lot of NANs (31.4%)

# %%
data.drop('Market Category', axis=1, inplace=True)

# %% [markdown]
# Let's do sanity checks to verify all went well

# %%
data.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11914.000000      11914.000000     11914.000000
# mean    2010.384338    248.365117          5.614655         3.436377
# std        7.579740    110.023455          1.800554         0.881184
# min     1990.000000      0.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    225.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.610710     19.733255   1554.911197  4.059474e+04
# std        8.340396      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      111.000000    137.000000   5657.000000  2.065902e+06

# %%
missing_zero_values_table(data)
# Out:
# Your selected dataframe has 15 columns and 11914 Rows.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Zero Values, Missing Values, % of Total Values, Data Type]
# Index: []

# %% [markdown]
# So all worked well in handling the missing values. Now lets move on to some visualization to get better feel of relationship of different variables with the price

# %% [markdown]
# # Visualization

# %%
data.plot(x='MSRP', y='Year', kind='scatter', figsize=(10, 7.5), title='Price over the Model Year', grid=True, fontsize=12)
plt.show()

# %% [markdown]
# Let's analyze models with price > 1000000

# %%
data[data['MSRP'] > 1000000]
# Out:
#               Make        Model  Year             Engine Fuel Type  Engine HP  \
# 6350       Maybach    Landaulet  2011  premium unleaded (required)      620.0
# 6351       Maybach    Landaulet  2012  premium unleaded (required)      620.0
# 8486   Lamborghini     Reventon  2008  premium unleaded (required)      650.0
# 11362      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11363      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364      Bugatti  Veyron 16.4  2009  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 6350               12.0         AUTOMATIC  rear wheel drive              4.0
# 6351               12.0         AUTOMATIC  rear wheel drive              4.0
# 8486               12.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11362              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11363              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11364              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity     MSRP
# 6350         Large   Convertible           16        10          67  1380000
# 6351         Large   Convertible           16        10          67  1382750
# 8486       Compact         Coupe           14         9        1158  1500000
# 11362      Compact         Coupe           14         8         820  2065902
# 11363      Compact         Coupe           14         8         820  1500000
# 11364      Compact         Coupe           14         8         820  1705769

# %% [markdown]
# So, these are just luxurious sports cars, not any outliers

# %% [markdown]
# Also, new cars have high prices generally.

# %%
fig = plt.figure(figsize=(15, 12))
sns.stripplot(data=data, x='MSRP', y='Make', jitter=0.1, size=5)
plt.xlim(0, 2200000)
plt.xlabel('Price', size=12)
plt.ylabel('Make', size=12)
plt.title('Distribution of Price by Make', size=16)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(15, 12))
sns.boxplot(data=data, x='Engine Fuel Type', y='MSRP')
plt.xlabel('Fuel Type', size=12)
plt.xticks(rotation=45)
plt.ylabel('Price', size=12)
plt.title('Distribution of Price by Fuel Type', size=16)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(10, 8))
sns.violinplot(data=data, x='Vehicle Size', y='MSRP')
plt.xlabel('Vehicle Size', size=12)
plt.ylabel('Price', size=12)
plt.title('Distribution of Price by Vehicle Size', size=16)
plt.grid()
plt.show()

# %%
data.plot(x='MSRP', y='city mpg', kind='scatter', figsize=(12, 9), grid=True)
plt.xlabel('Price', size=12)
plt.ylabel('City MPG', size=12)
plt.title('Distribution of Price by City Mileage', size=16)
plt.show()

# %% [markdown]
# Cars with higher price ranges have less mileage

# %%
data.plot(x='MSRP', y='Popularity', kind='scatter', figsize=(12, 9), grid=True)
plt.xlabel('Price', size=12)
plt.ylabel('Popularity', size=12)
plt.title('Distribution of Price by Popularity', size=16)
plt.show()

# %% [markdown]
# Seems like cars with higher price range are less popular!

# %% [markdown]
# # Feature Engineering
